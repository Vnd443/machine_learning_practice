# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Basic').getOrCreate()

# %%
data=[('vnd',24),('naveen',24),('Venky',25)]

# %%
df=spark.createDataFrame(data,['Name','Age'])

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.describe().show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.describe().show()
#
# NameError: name 'df' is not defined

# %%
from pyspark.sql.types import (StructField,StringType,IntergerType,StructType)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pyspark.sql.types import (StructField,StringType,IntergerType,StructType)
#
# ImportError: cannot import name 'IntergerType' from 'pyspark.sql.types' (C:\Users\003LGU744\anaconda3\Lib\site-packages\pyspark\sql\types.py)

# %%
conda install pyspark
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\003LGU744\anaconda3
#
#   added / updated specs:
#     - pyspark
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.12.3         |  py311haa95532_0         156 KB
#     botocore-1.34.69           |  py311haa95532_0         7.3 MB
#     certifi-2024.2.2           |  py311haa95532_0         162 KB
#     colorama-0.4.6             |  py311haa95532_0          36 KB
#     docutils-0.18.1            |  py311haa95532_3         881 KB
#     fsspec-2024.3.1            |  py311haa95532_0         374 KB
#     jsonpatch-1.33             |  py311haa95532_1          63 KB
#     openssl-3.0.13             |       h2bbff1b_1         7.5 MB
#     packaging-23.2             |  py311haa95532_0         173 KB
#     py4j-0.10.9.7              |  py311haa95532_0         306 KB
#     pyspark-3.4.1              |  py311haa95532_0       292.8 MB
#     s3fs-2024.3.1              |  py311haa95532_0          80 KB
#     ------------------------------------------------------------
#                                            Total:       309.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   botocore           pkgs/main/win-64::botocore-1.34.69-py311haa95532_0
#   colorama           pkgs/main/win-64::colorama-0.4.6-py311haa95532_0
#   docutils           pkgs/main/win-64::docutils-0.18.1-py311haa95532_3
#   jsonpatch          pkgs/main/win-64::jsonpatch-1.33-py311haa95532_1
#   packaging          pkgs/main/win-64::packaging-23.2-py311haa95532_0
#   py4j               pkgs/main/win-64::py4j-0.10.9.7-py311haa95532_0
#   pyspark            pkgs/main/win-64::pyspark-3.4.1-py311haa95532_0
#
# The following packages will be UPDATED:
#
#   aiobotocore                         2.5.0-py311haa95532_0 --> 2.12.3-py311haa95532_0
#   ca-certificates                     2023.08.22-haa95532_0 --> 2024.3.11-haa95532_0
#   certifi                         2023.7.22-py311haa95532_0 --> 2024.2.2-py311haa95532_0
#   fsspec                           2023.4.0-py311haa95532_0 --> 2024.3.1-py311haa95532_0
#   openssl                                 3.0.10-h2bbff1b_2 --> 3.0.13-h2bbff1b_1
#   s3fs                             2023.4.0-py311haa95532_0 --> 2024.3.1-py311haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# packaging-23.2       | 173 KB    |            |   0%
#
# openssl-3.0.13       | 7.5 MB    |            |   0%
#
#
# colorama-0.4.6       | 36 KB     |            |   0%
#
#
#
# certifi-2024.2.2     | 162 KB    |            |   0%
#
#
#
#
# py4j-0.10.9.7        | 306 KB    |            |   0%
#
#
#
#
#
# aiobotocore-2.12.3   | 156 KB    |            |   0%
#
#
#
#
#
#
# s3fs-2024.3.1        | 80 KB     |            |   0%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   0%
#
#
#
#
#
#
#
#
# docutils-0.18.1      | 881 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# fsspec-2024.3.1      | 374 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.33       | 63 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    |            |   0%
#
#
#
# certifi-2024.2.2     | 162 KB    | 9          |  10%
# packaging-23.2       | 173 KB    | 9          |   9%
#
#
# colorama-0.4.6       | 36 KB     | ####4      |  45%
#
# openssl-3.0.13       | 7.5 MB    |            |   0%
#
#
#
#
# py4j-0.10.9.7        | 306 KB    | 5          |   5%
#
#
#
#
#
# aiobotocore-2.12.3   | 156 KB    | #          |  10%
#
#
#
#
#
#
# s3fs-2024.3.1        | 80 KB     | #9         |  20%
#
# openssl-3.0.13       | 7.5 MB    | 3          |   3%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   0%
#
#
#
#
#
#
#
#
# docutils-0.18.1      | 881 KB    | 1          |   2%
#
# openssl-3.0.13       | 7.5 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.33       | 63 KB     | ##5        |  26%
#
#
#
#
#
#
#
#
#
# fsspec-2024.3.1      | 374 KB    | 4          |   4%
#
#
#
# certifi-2024.2.2     | 162 KB    | ########## | 100%
#
#
#
# certifi-2024.2.2     | 162 KB    | ########## | 100%
#
#
# colorama-0.4.6       | 36 KB     | ########## | 100%
#
#
# colorama-0.4.6       | 36 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# docutils-0.18.1      | 881 KB    | #####      |  51%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   0%
#
# openssl-3.0.13       | 7.5 MB    | #7         |  18%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   0%
#
#
#
#
#
#
#
#
# docutils-0.18.1      | 881 KB    | #######9   |  80%
#
# openssl-3.0.13       | 7.5 MB    | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    |            |   0%
# packaging-23.2       | 173 KB    | ########## | 100%
# packaging-23.2       | 173 KB    | ########## | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   0%
#
# openssl-3.0.13       | 7.5 MB    | ###6       |  36%
#
#
#
#
#
# aiobotocore-2.12.3   | 156 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | 2          |   3%
#
#
#
#
#
# aiobotocore-2.12.3   | 156 KB    | ########## | 100%
#
#
#
#
# py4j-0.10.9.7        | 306 KB    | ########## | 100%
#
#
#
#
# py4j-0.10.9.7        | 306 KB    | ########## | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   1%
#
#
#
#
#
#
# s3fs-2024.3.1        | 80 KB     | ########## | 100%
#
#
#
#
#
#
# s3fs-2024.3.1        | 80 KB     | ########## | 100%
#
# openssl-3.0.13       | 7.5 MB    | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.33       | 63 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.33       | 63 KB     | ########## | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | #1         |  12%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  |            |   1%
#
# openssl-3.0.13       | 7.5 MB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | #9         |  19%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 1          |   1%
#
# openssl-3.0.13       | 7.5 MB    | #######    |  71%
#
#
#
#
#
#
#
#
#
# fsspec-2024.3.1      | 374 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# fsspec-2024.3.1      | 374 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ###6       |  37%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 1          |   1%
#
# openssl-3.0.13       | 7.5 MB    | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ####6      |  47%
#
# openssl-3.0.13       | 7.5 MB    | #########2 |  93%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | #####4     |  54%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ######7    |  67%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ########   |  80%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 2          |   2%
#
#
#
#
#
#
#
#
# docutils-0.18.1      | 881 KB    | ########## | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | #########  |  90%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 2          |   3%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 2          |   3%
#
# openssl-3.0.13       | 7.5 MB    | ########## | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 2          |   3%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 3          |   3%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 3          |   3%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 3          |   4%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 4          |   4%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 4          |   4%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 4          |   5%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 5          |   5%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 5          |   5%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 5          |   6%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 6          |   6%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 6          |   6%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 6          |   7%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 7          |   7%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 7          |   8%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 8          |   8%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 8          |   9%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 9          |   9%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | 9          |  10%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #          |  10%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #          |  11%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #1         |  11%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #1         |  12%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #2         |  12%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #3         |  13%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #3         |  14%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #4         |  14%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #4         |  15%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #5         |  15%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #5         |  16%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #6         |  17%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #7         |  17%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #7         |  18%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #8         |  18%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #8         |  19%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.69     | 7.3 MB    | ########## | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #9         |  20%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##         |  21%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##1        |  21%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##2        |  22%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##2        |  23%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##3        |  23%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##3        |  24%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##4        |  25%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##5        |  25%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##5        |  26%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##6        |  26%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##7        |  28%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##8        |  28%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##8        |  29%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##9        |  29%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ##9        |  30%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###        |  31%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###1       |  32%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###2       |  32%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###2       |  33%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###3       |  33%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###3       |  34%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###4       |  34%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###4       |  35%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###5       |  35%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###5       |  36%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###6       |  37%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###7       |  37%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###7       |  38%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###8       |  38%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###8       |  39%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###9       |  39%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ###9       |  40%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####       |  41%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####1      |  41%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####1      |  42%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####2      |  42%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####3      |  43%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####3      |  44%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####4      |  45%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####5      |  45%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####5      |  46%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####6      |  46%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####6      |  47%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####7      |  48%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####8      |  48%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ####9      |  49%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####      |  50%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####      |  51%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####1     |  51%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####1     |  51%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####1     |  52%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####2     |  53%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####3     |  53%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####3     |  54%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####4     |  54%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####4     |  55%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####5     |  55%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####6     |  56%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####6     |  57%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####7     |  58%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####8     |  59%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #####9     |  60%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######     |  60%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######1    |  61%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######1    |  62%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######2    |  62%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######2    |  63%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######3    |  63%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######4    |  64%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######4    |  65%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######5    |  65%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######5    |  66%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######6    |  66%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######6    |  67%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######7    |  67%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######7    |  68%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######8    |  68%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ######8    |  69%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######    |  70%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######    |  71%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######1   |  71%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######2   |  72%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######3   |  73%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######3   |  74%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######4   |  74%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######4   |  75%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######5   |  75%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######6   |  76%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######6   |  77%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######7   |  77%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######7   |  78%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######8   |  79%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #######9   |  80%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########   |  80%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########   |  81%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########1  |  81%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########1  |  82%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########2  |  82%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########3  |  83%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########3  |  84%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########4  |  84%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########4  |  85%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########5  |  85%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########5  |  86%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########6  |  87%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########7  |  87%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########7  |  88%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########8  |  88%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########9  |  89%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########9  |  90%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########  |  90%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########  |  91%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########1 |  91%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########1 |  92%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########2 |  92%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########3 |  93%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########3 |  94%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########4 |  95%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########5 |  95%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########5 |  96%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########6 |  96%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########6 |  97%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########7 |  98%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########8 |  98%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########8 |  99%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | #########9 | 100%
#
#
#
#
#
#
#
# pyspark-3.4.1        | 292.8 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::aiobotocore==2.5.0=py311haa95532_0
#   - defaults/win-64::anaconda-catalogs==0.2.0=py311haa95532_0
#   - defaults/win-64::anaconda-client==1.12.1=py311haa95532_0
#   - defaults/win-64::anaconda-cloud-auth==0.1.3=py311haa95532_0
#   - defaults/win-64::anaconda-navigator==2.5.0=py311haa95532_0
#   - defaults/win-64::anaconda-project==0.11.1=py311haa95532_0
#   - defaults/win-64::astropy==5.1=py311h5bb9823_0
#   - defaults/win-64::black==23.3.0=py311haa95532_0
#   - defaults/noarch::bleach==4.1.0=pyhd3eb1b0_0
#   - defaults/win-64::bokeh==3.2.1=py311h746a85d_0
#   - defaults/win-64::click==8.0.4=py311haa95532_0
#   - defaults/win-64::conda==23.7.4=py311haa95532_0
#   - defaults/win-64::conda-build==3.26.1=py311haa95532_0
#   - defaults/win-64::conda-index==0.3.0=py311haa95532_0
#   - defaults/win-64::conda-libmamba-solver==23.7.0=py311haa95532_0
#   - defaults/win-64::conda-repo-cli==1.0.75=py311haa95532_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/win-64::dask==2023.6.0=py311haa95532_0
#   - defaults/win-64::dask-core==2023.6.0=py311haa95532_0
#   - defaults/win-64::datasets==2.12.0=py311haa95532_0
#   - defaults/win-64::datashader==0.15.2=py311haa95532_0
#   - defaults/win-64::distributed==2023.6.0=py311haa95532_0
#   - defaults/win-64::flask==2.2.2=py311haa95532_0
#   - defaults/win-64::holoviews==1.17.1=py311haa95532_0
#   - defaults/win-64::huggingface_hub==0.15.1=py311haa95532_0
#   - defaults/win-64::hvplot==0.8.4=py311haa95532_0
#   - defaults/win-64::intake==0.6.8=py311haa95532_0
#   - defaults/win-64::ipykernel==6.25.0=py311h746a85d_0
#   - defaults/win-64::ipython==8.15.0=py311haa95532_0
#   - defaults/win-64::ipywidgets==8.0.4=py311haa95532_0
#   - defaults/win-64::jupyter==1.0.0=py311haa95532_8
#   - defaults/win-64::jupyterlab==3.6.3=py311haa95532_0
#   - defaults/win-64::jupyterlab_server==2.22.0=py311haa95532_0
#   - defaults/win-64::jupyter_console==6.6.3=py311haa95532_0
#   - defaults/win-64::jupyter_server==1.23.4=py311haa95532_0
#   - defaults/win-64::jupyter_server_fileid==0.9.0=py311haa95532_0
#   - defaults/win-64::jupyter_server_ydoc==0.8.0=py311haa95532_1
#   - defaults/win-64::matplotlib==3.7.2=py311haa95532_0
#   - defaults/win-64::matplotlib-base==3.7.2=py311hf62ec03_0
#   - defaults/win-64::navigator-updater==0.4.0=py311haa95532_1
#   - defaults/win-64::nbclassic==0.5.5=py311haa95532_0
#   - defaults/win-64::nbconvert==6.5.4=py311haa95532_0
#   - defaults/win-64::nltk==3.8.1=py311haa95532_0
#   - defaults/win-64::notebook==6.5.4=py311haa95532_1
#   - defaults/win-64::notebook-shim==0.2.2=py311haa95532_0
#   - defaults/win-64::numpydoc==1.5.0=py311haa95532_0
#   - defaults/win-64::panel==1.2.3=py311haa95532_0
#   - defaults/win-64::pylint==2.16.2=py311haa95532_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/win-64::pyqt==5.15.7=py311hd77b12b_0
#   - defaults/win-64::pyqt5-sip==12.11.0=py311hd77b12b_0
#   - defaults/win-64::pyqtwebengine==5.15.7=py311hd77b12b_0
#   - defaults/win-64::pytables==3.8.0=py311h4671533_3
#   - defaults/win-64::pytest==7.4.0=py311haa95532_0
#   - defaults/win-64::python-dotenv==0.21.0=py311haa95532_0
#   - defaults/win-64::python-lsp-black==1.2.1=py311haa95532_0
#   - defaults/win-64::python-lsp-server==1.7.2=py311haa95532_0
#   - defaults/win-64::pytoolconfig==1.2.5=py311haa95532_1
#   - defaults/win-64::qtawesome==1.2.2=py311haa95532_0
#   - defaults/win-64::qtconsole==5.4.2=py311haa95532_0
#   - defaults/win-64::qtpy==2.2.0=py311haa95532_0
#   - defaults/win-64::rope==1.7.0=py311haa95532_0
#   - defaults/win-64::s3fs==2023.4.0=py311haa95532_0
#   - defaults/win-64::scikit-image==0.20.0=py311h3513d60_0
#   - defaults/win-64::scrapy==2.8.0=py311haa95532_0
#   - defaults/win-64::seaborn==0.12.2=py311haa95532_0
#   - defaults/win-64::sip==6.6.2=py311hd77b12b_0
#   - defaults/win-64::sphinx==5.0.2=py311haa95532_0
#   - defaults/win-64::spyder==5.4.3=py311haa95532_1
#   - defaults/win-64::spyder-kernels==2.4.4=py311haa95532_0
#   - defaults/win-64::statsmodels==0.14.0=py311hd7041d2_0
#   - defaults/win-64::tqdm==4.65.0=py311h746a85d_0
#   - defaults/win-64::transformers==4.32.1=py311haa95532_0
#   - defaults/win-64::xarray==2023.6.0=py311haa95532_0
#   - defaults/win-64::_anaconda_depends==2023.09=py311_mkl_1
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# RemoveError: 'jsonpatch' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'packaging' is a dependency of conda and cannot be removed from
# conda's operating environment.
